# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from matplotlib.pyplot import figure

# %%
df_iphone = pd.read_csv("rssi-distance-iphone.csv")
df_iphone
# Out:
#             id  phone  rssi_raw  rssi_median  distance
# 0    509757740      1     -81.0        -82.5       0.5
# 1    509757740      1     -80.0        -82.0       0.5
# 2    509757740      1     -84.0        -82.5       0.5
# 3    509757740      1     -81.0        -82.0       1.5
# 4    509757740      1     -80.0        -81.5       1.5
# ..         ...    ...       ...          ...       ...
# 586  509757740      1     -97.0        -93.5       0.5
# 587  509757740      1     -97.0        -94.0       0.5
# 588  509757740      1     -94.0        -94.0       0.5
# 589  509757740      1     -89.0        -94.0       0.5
# 590  509757740      1     -96.0        -95.5       1.5
#
# [591 rows x 5 columns]

# %%
figure(figsize=(8, 6), dpi=80)

sns.lineplot(x=np.array(df_iphone.index), y='rssi_raw', data=df_iphone)
sns.lineplot(x=np.array(df_iphone.index), y='rssi_median', data=df_iphone)
# Out:
# <AxesSubplot:ylabel='rssi_raw'>

# %%
figure(figsize=(8, 6), dpi=80)
sns.lineplot(x=np.array(df_iphone.index), y='distance', data=df_iphone)
# Out:
# <AxesSubplot:ylabel='distance'>

# %%
df_android = pd.read_csv("rssi-distance-android.csv")
df_android
# Out:
#              id  phone  rssi_raw  rssi_median  distance
# 0     327649634      0     -54.0        -53.0       0.5
# 1     327649634      0     -54.0        -53.0       0.5
# 2     327649634      0     -53.0        -53.0       0.5
# 3     327649634      0     -52.0        -53.0       0.5
# 4     327649634      0     -52.0        -53.0       0.5
# ...         ...    ...       ...          ...       ...
# 1584  327649634      0     -65.0        -61.0       1.5
# 1585  327649634      0     -67.0        -61.0       1.5
# 1586  327649634      0     -68.0        -61.0       1.5
# 1587  327649634      0     -65.0        -61.5       1.5
# 1588  327649634      0     -65.0        -62.0       1.5
#
# [1589 rows x 5 columns]

# %%
figure(figsize=(8, 6), dpi=80)

sns.lineplot(x=np.array(df_android.index), y='rssi_raw', data=df_android)
sns.lineplot(x=np.array(df_android.index), y='rssi_median', data=df_android)
# Out:
# <AxesSubplot:ylabel='rssi_raw'>

# %%
figure(figsize=(8, 6), dpi=80)
sns.lineplot(x=np.array(df_android.index), y='distance', data=df_android)
# Out:
# <AxesSubplot:ylabel='distance'>
