# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from matplotlib.pyplot import figure

# %%
id1 = 716634673
id2 = 690864300
id3 = 281371689
id4 = 327649634

# %%
df1 = pd.read_csv("run1/rssi-distance-android-716634673.csv")
df1.reset_index(inplace=True)
df12 = df1[df1['id'] == id2]
df13 = df1[df1['id'] == id3]
df14 = df1[df1['id'] == id4]

# %%
figure(figsize=(15, 6), dpi=80)

df = df13
sns.lineplot(x='index', y='rssi_raw', data=df)
sns.lineplot(x='index', y='rssi_median', data=df)
sns.lineplot(x='index', y='rssi_kalman', data=df)

figure(figsize=(15, 6), dpi=80)
sns.lineplot(x='index', y='distance', data=df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='distance'>

# %%
df2 = pd.read_csv("run1/rssi-distance-android-6908643000.csv")
df2.reset_index(inplace=True)
df21 = df2[df2['id'] == id1]
df23 = df2[df2['id'] == id3]
df24 = df2[df2['id'] == id4]

# %%
figure(figsize=(15, 6), dpi=80)

df = df21
sns.lineplot(x='index', y='rssi_raw', data=df)
sns.lineplot(x='index', y='rssi_median', data=df)
sns.lineplot(x='index', y='rssi_kalman', data=df)

figure(figsize=(15, 6), dpi=80)
sns.lineplot(x='index', y='distance', data=df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='distance'>

# %%
df3 = pd.read_csv("run1/rssi-distance-iphone-281371689.csv")
df3.reset_index(inplace=True)
df31 = df3[df3['id'] == id1]
df32 = df3[df3['id'] == id2]
df34 = df3[df3['id'] == id4]

# %%
figure(figsize=(15, 6), dpi=80)

df = df34
sns.lineplot(x='index', y='rssi_raw', data=df)
sns.lineplot(x='index', y='rssi_median', data=df)
sns.lineplot(x='index', y='rssi_kalman', data=df)

figure(figsize=(15, 6), dpi=80)
sns.lineplot(x='index', y='distance', data=df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='distance'>

# %%
df4 = pd.read_csv("run1/rssi-distance-iphone-327649634.csv")
df4.reset_index(inplace=True)
df41 = df4[df4['id'] == id1]
df42 = df4[df4['id'] == id2]
df43 = df4[df4['id'] == id3]

# %%
figure(figsize=(15, 6), dpi=80)

df = df43
sns.lineplot(x='index', y='rssi_raw', data=df)
sns.lineplot(x='index', y='rssi_median', data=df)
sns.lineplot(x='index', y='rssi_kalman', data=df)

figure(figsize=(15, 6), dpi=80)
sns.lineplot(x='index', y='distance', data=df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='distance'>
